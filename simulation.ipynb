# %%
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.set_loglevel('WARNING')
from run import main
# Out:
# pygame 2.2.0 (SDL 2.0.22, Python 3.7.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
"""
    start_time: the start time of the simulation (can only be used when you have saved state at that given timestamp)
    finish_time: the total simulation time
    checkpoints: a list of simulation timestamp for state saving e.g. [1000, 5000, 7000]
    scheme: simultaneously, randomly, alternatively, None
"""
main(start_time=0, finish_time=5000, checkpoints=[1000, 3000, 5000, 7000], scheme='alternatively')
# Out:
# Adversary: Start SCAN_HOST at 0.0s.
# MTD: CompleteTopologyShuffle triggered 0.0s
# MTD: CompleteTopologyShuffle deployed in the network at 0.0s.
# Adversary: Processed SCAN_HOST at 2.0s.
# Adversary: Start ENUM_HOST at 2.0s.
# Adversary: Processed ENUM_HOST at 5.0s.
# Adversary: Start SCAN_PORT at 5.0s.
# Adversary: Processed SCAN_PORT at 9.0s.
# Adversary: Start EXPLOIT_VULN at 9.0s.
# MTD: CompleteTopologyShuffle finished in 10.8s at 10.8s.
# MTD: Interrupted EXPLOIT_VULN at 10.8s!
# Adversary: Restarting with SCAN_HOST at 12.8s!
# Adversary: Start SCAN_HOST at 12.8s.
# Adversary: Processed SCAN_HOST at 14.8s.
# Adversary: Start ENUM_HOST at 14.8s.
# Adversary: Processed ENUM_HOST at 17.8s.
# Adversary: Start SCAN_PORT at 17.8s.
# Adversary: Processed SCAN_PORT at 21.8s.
# Adversary: Start EXPLOIT_VULN at 21.8s.
# Adversary: Processed EXPLOIT_VULN at 27.5s.
# Adversary: Start BRUTE_FORCE at 27.5s.
# Adversary: Processed BRUTE_FORCE at 30.5s.
# Adversary: Start ENUM_HOST at 30.5s.
# MTD: HostTopologyShuffle triggered 30.7s
# MTD: HostTopologyShuffle deployed in the network at 30.7s.
# Adversary: Processed ENUM_HOST at 33.5s.
# Adversary: Start SCAN_PORT at 33.5s.
# Adversary: Processed SCAN_PORT at 37.5s.
# Adversary: Start EXPLOIT_VULN at 37.5s.
# MTD: HostTopologyShuffle finished in 9.4s at 40.0s.
# MTD: Interrupted EXPLOIT_VULN at 40.0s!
# Adversary: Restarting with SCAN_HOST at 42.0s!
# Adversary: Start SCAN_HOST at 42.0s.
# Adversary: Processed SCAN_HOST at 44.0s.
# Adversary: Start ENUM_HOST at 44.0s.
# Adversary: Processed ENUM_HOST at 47.0s.
# Adversary: Start SCAN_PORT at 47.0s.
# Adversary: Processed SCAN_PORT at 51.0s.
# Adversary: Start EXPLOIT_VULN at 51.0s.
# Adversary: Processed EXPLOIT_VULN at 56.4s.
# Adversary: Host 0 has been compromised at 56.4s!
# Adversary: Start SCAN_NEIGHBOR at 56.4s.
# Adversary: Processed SCAN_NEIGHBOR at 58.4s.
# Adversary: Start ENUM_HOST at 58.4s.
# MTD: IPShuffle triggered 60.9s
# MTD: IPShuffle deployed in the network at 60.9s.
# Adversary: Processed ENUM_HOST at 61.4s.
# Adversary: Start SCAN_PORT at 61.4s.
# Adversary: Processed SCAN_PORT at 65.4s.
# Adversary: Start EXPLOIT_VULN at 65.4s.
# MTD: IPShuffle finished in 8.4s at 69.3s.
# MTD: Interrupted EXPLOIT_VULN at 69.3s!
# Adversary: Restarting with SCAN_HOST at 71.3s!
# Adversary: Start SCAN_HOST at 71.3s.
# Adversary: Processed SCAN_HOST at 73.3s.
# Adversary: Start ENUM_HOST at 73.3s.
# Adversary: Processed ENUM_HOST at 76.3s.
# Adversary: Start SCAN_PORT at 76.3s.
# Adversary: Processed SCAN_PORT at 80.3s.
# Adversary: Start EXPLOIT_VULN at 80.3s.
# Adversary: Processed EXPLOIT_VULN at 85.7s.
# Adversary: Start BRUTE_FORCE at 85.7s.
# Adversary: Processed BRUTE_FORCE at 88.7s.
# Adversary: Start ENUM_HOST at 88.7s.
# MTD: OSDiversity triggered 91.5s
# MTD: OSDiversity deployed in the network at 91.5s.
# Adversary: Processed ENUM_HOST at 91.7s.
# Adversary: Start SCAN_PORT at 91.7s.
# Adversary: Processed SCAN_PORT at 95.7s.
# Adversary: Start EXPLOIT_VULN at 95.7s.
# MTD: OSDiversity finished in 7.0s at 98.6s.
# MTD: Interrupted EXPLOIT_VULN at 98.6s!
# Adversary: Restarting with SCAN_PORT at 100.6s!
# Adversary: Start SCAN_PORT at 100.6s.
# Adversary: Processed SCAN_PORT at 104.6s.
# Adversary: Start EXPLOIT_VULN at 104.6s.
# Adversary: Processed EXPLOIT_VULN at 110.0s.
# Adversary: Host 1 has been compromised at 110.0s!
# Adversary: Start SCAN_NEIGHBOR at 110.0s.
# Adversary: Processed SCAN_NEIGHBOR at 112.0s.
# Adversary: Start ENUM_HOST at 112.0s.
# Adversary: Processed ENUM_HOST at 115.0s.
# Adversary: Start SCAN_PORT at 115.0s.
# Adversary: Processed SCAN_PORT at 119.0s.
# Adversary: Start EXPLOIT_VULN at 119.0s.
# MTD: PortShuffle triggered 121.8s
# MTD: PortShuffle deployed in the network at 121.8s.
# Adversary: Processed EXPLOIT_VULN at 124.8s.
# Adversary: Host 28 has been compromised at 124.8s!
# Adversary: Start SCAN_NEIGHBOR at 124.8s.
# Adversary: Processed SCAN_NEIGHBOR at 126.8s.
# Adversary: Start ENUM_HOST at 126.8s.
# MTD: PortShuffle finished in 6.6s at 128.4s.
# Adversary: Processed ENUM_HOST at 129.8s.
# Adversary: Start SCAN_PORT at 129.8s.
# Adversary: Processed SCAN_PORT at 133.8s.
# Adversary: Start EXPLOIT_VULN at 133.8s.
# Adversary: Processed EXPLOIT_VULN at 139.6s.
# Adversary: Host 31 has been compromised at 139.6s!
# Adversary: Start SCAN_NEIGHBOR at 139.6s.
# Adversary: Processed SCAN_NEIGHBOR at 141.6s.
# Adversary: Start ENUM_HOST at 141.6s.
# Adversary: Processed ENUM_HOST at 144.6s.
# Adversary: Start SCAN_PORT at 144.6s.
# Adversary: Processed SCAN_PORT at 148.6s.
# Adversary: Start EXPLOIT_VULN at 148.6s.
# MTD: ServiceDiversity triggered 151.9s
# MTD: ServiceDiversity deployed in the network at 151.9s.
# Adversary: Processed EXPLOIT_VULN at 154.6s.
# Adversary: Host 33 has been compromised at 154.6s!
# Adversary: Start SCAN_NEIGHBOR at 154.6s.
# Adversary: Processed SCAN_NEIGHBOR at 156.6s.
# Adversary: Start ENUM_HOST at 156.6s.
# Adversary: Processed ENUM_HOST at 159.6s.
# Adversary: Start ENUM_HOST at 159.6s.
# MTD: ServiceDiversity finished in 8.2s at 160.2s.
# Adversary: Processed ENUM_HOST at 162.6s.
# Adversary: Start ENUM_HOST at 162.6s.
# Adversary: Processed ENUM_HOST at 165.6s.
# Adversary: Start SCAN_PORT at 165.6s.
# Adversary: Processed SCAN_PORT at 169.6s.
# Adversary: Start EXPLOIT_VULN at 169.6s.
# Adversary: Processed EXPLOIT_VULN at 174.7s.
# Adversary: Host 27 has been compromised at 174.7s!
# Adversary: Start SCAN_NEIGHBOR at 174.7s.
# Adversary: Processed SCAN_NEIGHBOR at 176.7s.
# Adversary: Start ENUM_HOST at 176.7s.
# Adversary: Processed ENUM_HOST at 179.7s.
# Adversary: Start ENUM_HOST at 179.7s.
# Adversary: Processed ENUM_HOST at 182.7s.
# Adversary: Start SCAN_PORT at 182.7s.
# MTD: CompleteTopologyShuffle triggered 183.0s
# MTD: CompleteTopologyShuffle deployed in the network at 183.0s.
# Adversary: Processed SCAN_PORT at 186.7s.
# Adversary: Start EXPLOIT_VULN at 186.7s.
# Adversary: Processed EXPLOIT_VULN at 191.8s.
# Adversary: Host 29 has been compromised at 191.8s!
# Adversary: Start SCAN_NEIGHBOR at 191.8s.
# MTD: CompleteTopologyShuffle finished in 10.5s at 193.5s.
# MTD: Interrupted SCAN_NEIGHBOR at 193.5s!
# Adversary: Restarting with SCAN_HOST at 195.5s!
# Adversary: Start SCAN_HOST at 195.5s.
# Adversary: Processed SCAN_HOST at 197.5s.
# Adversary: Start ENUM_HOST at 197.5s.
# Adversary: Processed ENUM_HOST at 200.5s.
# Adversary: Start SCAN_PORT at 200.5s.
# Adversary: Processed SCAN_PORT at 204.5s.
# Adversary: Start EXPLOIT_VULN at 204.5s.
# Adversary: Processed EXPLOIT_VULN at 210.0s.
# Adversary: Host 25 has been compromised at 210.0s!
# Adversary: Start SCAN_NEIGHBOR at 210.0s.
# Adversary: Processed SCAN_NEIGHBOR at 212.0s.
# Adversary: Start ENUM_HOST at 212.0s.
# MTD: HostTopologyShuffle triggered 213.4s
# MTD: HostTopologyShuffle deployed in the network at 213.4s.
# Adversary: Processed ENUM_HOST at 215.0s.
# Adversary: Start ENUM_HOST at 215.0s.
# Adversary: Processed ENUM_HOST at 218.0s.
# Adversary: Start ENUM_HOST at 218.0s.
# Adversary: Processed ENUM_HOST at 221.0s.
# Adversary: Start ENUM_HOST at 221.0s.
# Adversary: Processed ENUM_HOST at 224.0s.
# Adversary: Start SCAN_PORT at 224.0s.
# MTD: HostTopologyShuffle finished in 11.1s at 224.5s.
# MTD: Interrupted SCAN_PORT at 224.5s!
# Adversary: Restarting with SCAN_HOST at 226.5s!
# Adversary: Start SCAN_HOST at 226.5s.
# Adversary: Processed SCAN_HOST at 228.5s.
# Adversary: Start ENUM_HOST at 228.5s.
# Adversary: Processed ENUM_HOST at 231.5s.
# Adversary: Start SCAN_PORT at 231.5s.
# Adversary: Processed SCAN_PORT at 235.5s.
# Adversary: Start EXPLOIT_VULN at 235.5s.
# Adversary: Processed EXPLOIT_VULN at 240.8s.
# Adversary: Host 17 has been compromised at 240.8s!
# Adversary: Start SCAN_NEIGHBOR at 240.8s.
# Adversary: Processed SCAN_NEIGHBOR at 242.8s.
# Adversary: Start ENUM_HOST at 242.8s.
# MTD: IPShuffle triggered 243.5s
# MTD: IPShuffle deployed in the network at 243.5s.
# Adversary: Processed ENUM_HOST at 245.8s.
# Adversary: Start ENUM_HOST at 245.8s.
# Adversary: Processed ENUM_HOST at 248.8s.
# Adversary: Start ENUM_HOST at 248.8s.
# MTD: IPShuffle finished in 8.1s at 251.6s.
# MTD: Interrupted ENUM_HOST at 251.6s!
# Adversary: Restarting with SCAN_HOST at 253.6s!
# Adversary: Start SCAN_HOST at 253.6s.
# Adversary: Processed SCAN_HOST at 255.6s.
# Adversary: Start ENUM_HOST at 255.6s.
# Adversary: Processed ENUM_HOST at 258.6s.
# Adversary: Start SCAN_PORT at 258.6s.
# Adversary: Processed SCAN_PORT at 262.6s.
# Adversary: Start EXPLOIT_VULN at 262.6s.
# Adversary: Processed EXPLOIT_VULN at 269.6s.
# Adversary: Host 21 has been compromised at 269.6s!
# Adversary: Start SCAN_NEIGHBOR at 269.6s.
# Adversary: Processed SCAN_NEIGHBOR at 271.6s.
# Adversary: Start ENUM_HOST at 271.6s.
# MTD: OSDiversity triggered 273.8s
# MTD: OSDiversity deployed in the network at 273.8s.
# Adversary: Processed ENUM_HOST at 274.6s.
# Adversary: Start ENUM_HOST at 274.6s.
# Adversary: Processed ENUM_HOST at 277.6s.
# Adversary: Start SCAN_PORT at 277.6s.
# MTD: OSDiversity finished in 7.5s at 281.3s.
# MTD: Interrupted SCAN_PORT at 281.3s!
# Adversary: Restarting with SCAN_PORT at 283.3s!
# Adversary: Start SCAN_PORT at 283.3s.
# Adversary: Processed SCAN_PORT at 287.3s.
# Adversary: Start EXPLOIT_VULN at 287.3s.
# Adversary: Processed EXPLOIT_VULN at 292.5s.
# Adversary: Host 19 has been compromised at 292.5s!
# Adversary: Start SCAN_NEIGHBOR at 292.5s.
# Adversary: Processed SCAN_NEIGHBOR at 294.5s.
# Adversary: Start ENUM_HOST at 294.5s.
# Adversary: Processed ENUM_HOST at 297.5s.
# Adversary: Start ENUM_HOST at 297.5s.
# Adversary: Processed ENUM_HOST at 300.5s.
# Adversary: Start ENUM_HOST at 300.5s.
# Adversary: Processed ENUM_HOST at 303.5s.
# Adversary: Start ENUM_HOST at 303.5s.
# MTD: PortShuffle triggered 303.8s
# MTD: PortShuffle deployed in the network at 303.8s.
# Adversary: Processed ENUM_HOST at 306.5s.
# Adversary: Start SCAN_PORT at 306.5s.
# MTD: PortShuffle finished in 6.1s at 309.9s.
# MTD: Interrupted SCAN_PORT at 309.9s!
# Adversary: Restarting with SCAN_PORT at 311.9s!
# Adversary: Start SCAN_PORT at 311.9s.
# Adversary: Processed SCAN_PORT at 315.9s.
# Adversary: Start EXPLOIT_VULN at 315.9s.
# Adversary: Processed EXPLOIT_VULN at 320.9s.
# Adversary: Host 34 has been compromised at 320.9s!
# Adversary: Start SCAN_NEIGHBOR at 320.9s.
# Adversary: Processed SCAN_NEIGHBOR at 322.9s.
# Adversary: Start ENUM_HOST at 322.9s.
# Adversary: Processed ENUM_HOST at 325.9s.
# Adversary: Start SCAN_PORT at 325.9s.
# Adversary: Processed SCAN_PORT at 329.9s.
# Adversary: Start EXPLOIT_VULN at 329.9s.
# MTD: ServiceDiversity triggered 334.1s
# MTD: ServiceDiversity deployed in the network at 334.1s.
# Adversary: Processed EXPLOIT_VULN at 334.9s.
# Adversary: Host 36 has been compromised at 334.9s!
# Adversary: Start SCAN_NEIGHBOR at 334.9s.
# Adversary: Processed SCAN_NEIGHBOR at 336.9s.
# Adversary: Start ENUM_HOST at 336.9s.
# Adversary: Processed ENUM_HOST at 339.9s.
# Adversary: Start ENUM_HOST at 339.9s.
# MTD: ServiceDiversity finished in 8.1s at 342.2s.
# Adversary: Processed ENUM_HOST at 342.9s.
# Adversary: Start ENUM_HOST at 342.9s.
# Adversary: Processed ENUM_HOST at 345.9s.
# Adversary: Start SCAN_PORT at 345.9s.
# Adversary: Processed SCAN_PORT at 349.9s.
# Adversary: Start EXPLOIT_VULN at 349.9s.
# Adversary: Processed EXPLOIT_VULN at 355.0s.
# Adversary: Start BRUTE_FORCE at 355.0s.
# Adversary: Processed BRUTE_FORCE at 358.0s.
# Adversary: Start ENUM_HOST at 358.0s.
# Adversary: Processed ENUM_HOST at 361.0s.
# Adversary: Start ENUM_HOST at 361.0s.
# Adversary: Processed ENUM_HOST at 364.0s.
# Adversary: Start SCAN_PORT at 364.0s.
# MTD: CompleteTopologyShuffle triggered 364.1s
# MTD: CompleteTopologyShuffle deployed in the network at 364.1s.
# Adversary: Processed SCAN_PORT at 368.0s.
# Adversary: Start EXPLOIT_VULN at 368.0s.
# MTD: CompleteTopologyShuffle finished in 10.1s at 374.2s.
# MTD: Interrupted EXPLOIT_VULN at 374.2s!
# Adversary: Restarting with SCAN_HOST at 376.2s!
# Adversary: Start SCAN_HOST at 376.2s.
# Adversary: Processed SCAN_HOST at 378.2s.
# Adversary: Start ENUM_HOST at 378.2s.
# Adversary: Processed ENUM_HOST at 381.2s.
# Adversary: Start SCAN_PORT at 381.2s.
# Adversary: Processed SCAN_PORT at 385.2s.
# Adversary: Start EXPLOIT_VULN at 385.2s.
# Adversary: Processed EXPLOIT_VULN at 391.1s.
# Adversary: Start BRUTE_FORCE at 391.1s.
# Adversary: Processed BRUTE_FORCE at 394.1s.
# Adversary: Start ENUM_HOST at 394.1s.
# MTD: HostTopologyShuffle triggered 394.3s
# MTD: HostTopologyShuffle deployed in the network at 394.3s.
# Adversary: Processed ENUM_HOST at 397.1s.
# Adversary: Start SCAN_PORT at 397.1s.
# Adversary: Processed SCAN_PORT at 401.1s.
# Adversary: Start EXPLOIT_VULN at 401.1s.
# MTD: HostTopologyShuffle finished in 9.3s at 403.6s.
# MTD: Interrupted EXPLOIT_VULN at 403.6s!
# Adversary: Restarting with SCAN_HOST at 405.6s!
# Adversary: Start SCAN_HOST at 405.6s.
# Adversary: Processed SCAN_HOST at 407.6s.
# Adversary: Start ENUM_HOST at 407.6s.
# Adversary: Processed ENUM_HOST at 410.6s.
# Adversary: Start SCAN_PORT at 410.6s.
# Adversary: Processed SCAN_PORT at 414.6s.
# Adversary: Start EXPLOIT_VULN at 414.6s.
# Adversary: Processed EXPLOIT_VULN at 420.3s.
# Adversary: Host 27 has been compromised at 420.3s!
# Adversary: Start SCAN_NEIGHBOR at 420.3s.
# Adversary: Processed SCAN_NEIGHBOR at 422.3s.
# Adversary: Start ENUM_HOST at 422.3s.
# MTD: IPShuffle triggered 424.8s
# MTD: IPShuffle deployed in the network at 424.8s.
# Adversary: Processed ENUM_HOST at 425.3s.
# Adversary: Start SCAN_PORT at 425.3s.
# Adversary: Processed SCAN_PORT at 429.3s.
# Adversary: Start EXPLOIT_VULN at 429.3s.
# MTD: IPShuffle finished in 9.2s at 434.0s.
# MTD: Interrupted EXPLOIT_VULN at 434.0s!
# Adversary: Restarting with SCAN_HOST at 436.0s!
# Adversary: Start SCAN_HOST at 436.0s.
# Adversary: Processed SCAN_HOST at 438.0s.
# Adversary: Start ENUM_HOST at 438.0s.
# Adversary: Processed ENUM_HOST at 441.0s.
# Adversary: Start SCAN_PORT at 441.0s.
# Adversary: Processed SCAN_PORT at 445.0s.
# Adversary: Start EXPLOIT_VULN at 445.0s.
# Adversary: Processed EXPLOIT_VULN at 453.5s.
# Adversary: Host 21 has been compromised at 453.5s!
# Adversary: Start SCAN_NEIGHBOR at 453.5s.
# MTD: OSDiversity triggered 455.2s
# MTD: OSDiversity deployed in the network at 455.2s.
# Adversary: Processed SCAN_NEIGHBOR at 455.5s.
# Adversary: Start ENUM_HOST at 455.5s.
# Adversary: Processed ENUM_HOST at 458.5s.
# Adversary: Start ENUM_HOST at 458.5s.
# Adversary: Processed ENUM_HOST at 461.5s.
# Adversary: Start ENUM_HOST at 461.5s.
# MTD: OSDiversity finished in 7.2s at 462.5s.
# Adversary: Processed ENUM_HOST at 464.5s.
# Adversary: Start ENUM_HOST at 464.5s.
# Adversary: Processed ENUM_HOST at 467.5s.
# Adversary: Start SCAN_PORT at 467.5s.
# Adversary: Processed SCAN_PORT at 471.5s.
# Adversary: Start EXPLOIT_VULN at 471.5s.
# Adversary: Processed EXPLOIT_VULN at 476.9s.
# Adversary: Host 55 has been compromised at 476.9s!
# Adversary: Start SCAN_NEIGHBOR at 476.9s.
# Adversary: Processed SCAN_NEIGHBOR at 478.9s.
# Adversary: Start ENUM_HOST at 478.9s.
# Adversary: Processed ENUM_HOST at 481.9s.
# Adversary: Start SCAN_PORT at 481.9s.
# MTD: PortShuffle triggered 485.7s
# MTD: PortShuffle deployed in the network at 485.7s.
# Adversary: Processed SCAN_PORT at 485.9s.
# Adversary: Start EXPLOIT_VULN at 485.9s.
# Adversary: Processed EXPLOIT_VULN at 491.1s.
# Adversary: Host 56 has been compromised at 491.1s!
# Adversary: Start SCAN_NEIGHBOR at 491.1s.
# MTD: PortShuffle finished in 6.3s at 491.9s.
# Adversary: Processed SCAN_NEIGHBOR at 493.1s.
# Adversary: Start ENUM_HOST at 493.1s.
# Adversary: Processed ENUM_HOST at 496.1s.
# Adversary: Start SCAN_PORT at 496.1s.
# Adversary: Processed SCAN_PORT at 500.1s.
# Adversary: Start EXPLOIT_VULN at 500.1s.
# Adversary: Processed EXPLOIT_VULN at 505.7s.
# Adversary: Start BRUTE_FORCE at 505.7s.
# Adversary: Processed BRUTE_FORCE at 508.7s.
# Adversary: Start ENUM_HOST at 508.7s.
# Adversary: Processed ENUM_HOST at 511.7s.
# Adversary: Start SCAN_PORT at 511.7s.
# Adversary: Processed SCAN_PORT at 515.7s.
# Adversary: Start EXPLOIT_VULN at 515.7s.
# MTD: ServiceDiversity triggered 515.9s
# MTD: ServiceDiversity deployed in the network at 515.9s.
# Adversary: Processed EXPLOIT_VULN at 521.2s.
# Adversary: Host 24 has been compromised at 521.2s!
# Adversary: Start SCAN_NEIGHBOR at 521.2s.
# Adversary: Processed SCAN_NEIGHBOR at 523.2s.
# Adversary: Start ENUM_HOST at 523.2s.
# MTD: ServiceDiversity finished in 8.0s at 523.9s.
# Adversary: Processed ENUM_HOST at 526.2s.
# Adversary: Start ENUM_HOST at 526.2s.
# Adversary: Processed ENUM_HOST at 529.2s.
# Adversary: Start SCAN_PORT at 529.2s.
# Adversary: Processed SCAN_PORT at 533.2s.
# Adversary: Start EXPLOIT_VULN at 533.2s.
# Adversary: Processed EXPLOIT_VULN at 539.1s.
# Adversary: Host 29 has been compromised at 539.1s!
# Adversary: Start SCAN_NEIGHBOR at 539.1s.
# Adversary: Processed SCAN_NEIGHBOR at 541.1s.
# Adversary: Start ENUM_HOST at 541.1s.
# Adversary: Processed ENUM_HOST at 544.1s.
# Adversary: Start ENUM_HOST at 544.1s.
# MTD: CompleteTopologyShuffle triggered 546.0s
# MTD: CompleteTopologyShuffle deployed in the network at 546.0s.
# Adversary: Processed ENUM_HOST at 547.1s.
# Adversary: Start SCAN_PORT at 547.1s.
# Adversary: Processed SCAN_PORT at 551.1s.
# Adversary: Start EXPLOIT_VULN at 551.1s.
# Adversary: Processed EXPLOIT_VULN at 556.3s.
# Adversary: Host 34 has been compromised at 556.3s!
# Adversary: Start SCAN_NEIGHBOR at 556.3s.
# MTD: CompleteTopologyShuffle finished in 10.6s at 556.5s.
# MTD: Interrupted SCAN_NEIGHBOR at 556.5s!
# Adversary: Restarting with SCAN_HOST at 558.5s!
# Adversary: Start SCAN_HOST at 558.5s.
# Adversary: Processed SCAN_HOST at 560.5s.
# Adversary: Start ENUM_HOST at 560.5s.
# Adversary: Processed ENUM_HOST at 563.5s.
# Adversary: Start SCAN_PORT at 563.5s.
# Adversary: Processed SCAN_PORT at 567.5s.
# Adversary: Start EXPLOIT_VULN at 567.5s.
# Adversary: Processed EXPLOIT_VULN at 572.9s.
# Adversary: Host 35 has been compromised at 572.9s!
# Adversary: Start SCAN_NEIGHBOR at 572.9s.
# Adversary: Processed SCAN_NEIGHBOR at 574.9s.
# Adversary: Start ENUM_HOST at 574.9s.
# MTD: HostTopologyShuffle triggered 576.1s
# MTD: HostTopologyShuffle deployed in the network at 576.1s.
# Adversary: Processed ENUM_HOST at 577.9s.
# Adversary: Start ENUM_HOST at 577.9s.
# Adversary: Processed ENUM_HOST at 580.9s.
# Adversary: Start ENUM_HOST at 580.9s.
# Adversary: Processed ENUM_HOST at 583.9s.
# Adversary: Start ENUM_HOST at 583.9s.
# MTD: HostTopologyShuffle finished in 9.4s at 585.5s.
# MTD: Interrupted ENUM_HOST at 585.5s!
# Adversary: Restarting with SCAN_HOST at 587.5s!
# Adversary: Start SCAN_HOST at 587.5s.
# Adversary: Processed SCAN_HOST at 589.5s.
# Adversary: Start ENUM_HOST at 589.5s.
# Adversary: Processed ENUM_HOST at 592.5s.
# Adversary: Start SCAN_PORT at 592.5s.
# Adversary: Processed SCAN_PORT at 596.5s.
# Adversary: Start EXPLOIT_VULN at 596.5s.
# Adversary: Processed EXPLOIT_VULN at 602.0s.
# Adversary: Host 25 has been compromised at 602.0s!
# Adversary: Start SCAN_NEIGHBOR at 602.0s.
# Adversary: Processed SCAN_NEIGHBOR at 604.0s.
# Adversary: Start ENUM_HOST at 604.0s.
# MTD: IPShuffle triggered 606.9s
# MTD: IPShuffle deployed in the network at 606.9s.
# Adversary: Processed ENUM_HOST at 607.0s.
# Adversary: Start ENUM_HOST at 607.0s.
# Adversary: Processed ENUM_HOST at 610.0s.
# Adversary: Start ENUM_HOST at 610.0s.
# Adversary: Processed ENUM_HOST at 613.0s.
# Adversary: Start ENUM_HOST at 613.0s.
# MTD: IPShuffle finished in 8.4s at 615.3s.
# MTD: Interrupted ENUM_HOST at 615.3s!
# Adversary: Restarting with SCAN_HOST at 617.3s!
# Adversary: Start SCAN_HOST at 617.3s.
# Adversary: Processed SCAN_HOST at 619.3s.
# Adversary: Start ENUM_HOST at 619.3s.
# Adversary: Processed ENUM_HOST at 622.3s.
# Adversary: Start SCAN_PORT at 622.3s.
# Adversary: Processed SCAN_PORT at 626.3s.
# Adversary: Start EXPLOIT_VULN at 626.3s.
# Adversary: Processed EXPLOIT_VULN at 631.4s.
# Adversary: Start BRUTE_FORCE at 631.4s.
# Adversary: Processed BRUTE_FORCE at 634.4s.
# Adversary: Start ENUM_HOST at 634.4s.
# Adversary: Processed ENUM_HOST at 637.4s.
# Adversary: Start SCAN_PORT at 637.4s.
# MTD: OSDiversity triggered 638.1s
# MTD: OSDiversity deployed in the network at 638.1s.
# Adversary: Processed SCAN_PORT at 641.4s.
# Adversary: Start EXPLOIT_VULN at 641.4s.
# MTD: OSDiversity finished in 7.7s at 645.8s.
# MTD: Interrupted EXPLOIT_VULN at 645.8s!
# Adversary: Restarting with SCAN_PORT at 647.8s!
# Adversary: Start SCAN_PORT at 647.8s.
# Adversary: Processed SCAN_PORT at 651.8s.
# Adversary: Start EXPLOIT_VULN at 651.8s.
# Adversary: Processed EXPLOIT_VULN at 657.1s.
# Adversary: Host 44 has been compromised at 657.1s!
# Adversary: Start SCAN_NEIGHBOR at 657.1s.
# Adversary: Processed SCAN_NEIGHBOR at 659.1s.
# Adversary: Start ENUM_HOST at 659.1s.
# Adversary: Processed ENUM_HOST at 662.1s.
# Adversary: Start SCAN_PORT at 662.1s.
# Adversary: Processed SCAN_PORT at 666.1s.
# Adversary: Start EXPLOIT_VULN at 666.1s.
# MTD: PortShuffle triggered 668.9s
# MTD: PortShuffle deployed in the network at 668.9s.
# Adversary: Processed EXPLOIT_VULN at 671.6s.
# Adversary: Host 32 has been compromised at 671.6s!
# Adversary: Start SCAN_NEIGHBOR at 671.6s.
# Adversary: Processed SCAN_NEIGHBOR at 673.6s.
# Adversary: Start ENUM_HOST at 673.6s.
# MTD: PortShuffle finished in 6.7s at 675.6s.
# Adversary: Processed ENUM_HOST at 676.6s.
# Adversary: Start ENUM_HOST at 676.6s.
# Adversary: Processed ENUM_HOST at 679.6s.
# Adversary: Start SCAN_PORT at 679.6s.
# Adversary: Processed SCAN_PORT at 683.6s.
# Adversary: Start EXPLOIT_VULN at 683.6s.
# Adversary: Processed EXPLOIT_VULN at 690.6s.
# Adversary: Host 29 has been compromised at 690.6s!
# Adversary: Start SCAN_NEIGHBOR at 690.6s.
# Adversary: Processed SCAN_NEIGHBOR at 692.6s.
# Adversary: Start ENUM_HOST at 692.6s.
# Adversary: Processed ENUM_HOST at 695.6s.
# Adversary: Start ENUM_HOST at 695.6s.
# Adversary: Processed ENUM_HOST at 698.6s.
# Adversary: Start ENUM_HOST at 698.6s.
# MTD: ServiceDiversity triggered 699.6s
# MTD: ServiceDiversity deployed in the network at 699.6s.
# Adversary: Processed ENUM_HOST at 701.6s.
# Adversary: Start SCAN_PORT at 701.6s.
# Adversary: Processed SCAN_PORT at 705.6s.
# Adversary: Start EXPLOIT_VULN at 705.6s.
# MTD: ServiceDiversity finished in 8.4s at 708.0s.
# MTD: Interrupted EXPLOIT_VULN at 708.0s!
# Adversary: Restarting with SCAN_PORT at 710.0s!
# Adversary: Start SCAN_PORT at 710.0s.
# Adversary: Processed SCAN_PORT at 714.0s.
# Adversary: Start EXPLOIT_VULN at 714.0s.
# Adversary: Processed EXPLOIT_VULN at 719.6s.
# Adversary: Host 28 has been compromised at 719.6s!
# Adversary: Start SCAN_NEIGHBOR at 719.6s.
# Adversary: Processed SCAN_NEIGHBOR at 721.6s.
# Adversary: Start ENUM_HOST at 721.6s.
# Adversary: Processed ENUM_HOST at 724.6s.
# Adversary: Start SCAN_PORT at 724.6s.
# Adversary: Processed SCAN_PORT at 728.6s.
# Adversary: Start EXPLOIT_VULN at 728.6s.
# MTD: CompleteTopologyShuffle triggered 731.0s
# MTD: CompleteTopologyShuffle deployed in the network at 731.0s.
# Adversary: Processed EXPLOIT_VULN at 733.7s.
# Adversary: Host 26 has been compromised at 733.7s!
# Adversary: Start SCAN_NEIGHBOR at 733.7s.
# Adversary: Processed SCAN_NEIGHBOR at 735.7s.
# Adversary: Start ENUM_HOST at 735.7s.
# Adversary: Processed ENUM_HOST at 738.7s.
# Adversary: Start ENUM_HOST at 738.7s.
# MTD: CompleteTopologyShuffle finished in 10.1s at 741.1s.
# MTD: Interrupted ENUM_HOST at 741.1s!
# Adversary: Restarting with SCAN_HOST at 743.1s!
# Adversary: Start SCAN_HOST at 743.1s.
# Adversary: Processed SCAN_HOST at 745.1s.
# Adversary: Start ENUM_HOST at 745.1s.
# Adversary: Processed ENUM_HOST at 748.1s.
# Adversary: Start SCAN_PORT at 748.1s.
# Adversary: Processed SCAN_PORT at 752.1s.
# Adversary: Start EXPLOIT_VULN at 752.1s.
# Adversary: Processed EXPLOIT_VULN at 758.3s.
# Adversary: Host 33 has been compromised at 758.3s!
# Adversary: Start SCAN_NEIGHBOR at 758.3s.
# Adversary: Processed SCAN_NEIGHBOR at 760.3s.
# Adversary: Start ENUM_HOST at 760.3s.
# MTD: HostTopologyShuffle triggered 761.1s
# MTD: HostTopologyShuffle deployed in the network at 761.1s.
# Adversary: Processed ENUM_HOST at 763.3s.
# Adversary: Start ENUM_HOST at 763.3s.
# Adversary: Processed ENUM_HOST at 766.3s.
# Adversary: Start ENUM_HOST at 766.3s.
# Adversary: Processed ENUM_HOST at 769.3s.
# Adversary: Start ENUM_HOST at 769.3s.
# MTD: HostTopologyShuffle finished in 9.3s at 770.4s.
# MTD: Interrupted ENUM_HOST at 770.4s!
# Adversary: Restarting with SCAN_HOST at 772.4s!
# Adversary: Start SCAN_HOST at 772.4s.
# Adversary: Processed SCAN_HOST at 774.4s.
# Adversary: Start ENUM_HOST at 774.4s.
# Adversary: Processed ENUM_HOST at 777.4s.
# Adversary: Start SCAN_PORT at 777.4s.
# Adversary: Processed SCAN_PORT at 781.4s.
# Adversary: Start EXPLOIT_VULN at 781.4s.
# Adversary: Processed EXPLOIT_VULN at 788.1s.
# Adversary: Host 33 has been compromised at 788.1s!
# Adversary: Start SCAN_NEIGHBOR at 788.1s.
# Adversary: Processed SCAN_NEIGHBOR at 790.1s.
# Adversary: Start ENUM_HOST at 790.1s.
# MTD: IPShuffle triggered 791.8s
# MTD: IPShuffle deployed in the network at 791.8s.
# Adversary: Processed ENUM_HOST at 793.1s.
# Adversary: Start ENUM_HOST at 793.1s.
# Adversary: Processed ENUM_HOST at 796.1s.
# Adversary: Start ENUM_HOST at 796.1s.
# Adversary: Processed ENUM_HOST at 799.1s.
# Adversary: Start SCAN_PORT at 799.1s.
# MTD: IPShuffle finished in 8.3s at 800.1s.
# MTD: Interrupted SCAN_PORT at 800.1s!
# Adversary: Restarting with SCAN_HOST at 802.1s!
# Adversary: Start SCAN_HOST at 802.1s.
# Adversary: Processed SCAN_HOST at 804.1s.
# Adversary: Start ENUM_HOST at 804.1s.
# Adversary: Processed ENUM_HOST at 807.1s.
# Adversary: Start SCAN_PORT at 807.1s.
# Adversary: Processed SCAN_PORT at 811.1s.
# Adversary: Start EXPLOIT_VULN at 811.1s.
# Adversary: Processed EXPLOIT_VULN at 817.1s.
# Adversary: Host 34 has been compromised at 817.1s!
# Adversary: Start SCAN_NEIGHBOR at 817.1s.
# Adversary: Processed SCAN_NEIGHBOR at 819.1s.
# Adversary: Start ENUM_HOST at 819.1s.
# MTD: OSDiversity triggered 821.8s
# MTD: OSDiversity deployed in the network at 821.8s.
# Adversary: Processed ENUM_HOST at 822.1s.
# Adversary: Start ENUM_HOST at 822.1s.
# Adversary: Processed ENUM_HOST at 825.1s.
# Adversary: Start SCAN_PORT at 825.1s.
# MTD: OSDiversity finished in 7.0s at 828.8s.
# MTD: Interrupted SCAN_PORT at 828.8s!
# Adversary: Restarting with SCAN_PORT at 830.8s!
# Adversary: Start SCAN_PORT at 830.8s.
# Adversary: Processed SCAN_PORT at 834.8s.
# Adversary: Start EXPLOIT_VULN at 834.8s.
# Adversary: Processed EXPLOIT_VULN at 840.0s.
# Adversary: Host 52 has been compromised at 840.0s!
# Adversary: Start SCAN_NEIGHBOR at 840.0s.
# Adversary: Processed SCAN_NEIGHBOR at 842.0s.
# Adversary: Start ENUM_HOST at 842.0s.
# Adversary: Processed ENUM_HOST at 845.0s.
# Adversary: Start ENUM_HOST at 845.0s.
# Adversary: Processed ENUM_HOST at 848.0s.
# Adversary: Start ENUM_HOST at 848.0s.
# Adversary: Processed ENUM_HOST at 851.0s.
# Adversary: Start SCAN_PORT at 851.0s.
# MTD: PortShuffle triggered 852.9s
# MTD: PortShuffle deployed in the network at 852.9s.
# Adversary: Processed SCAN_PORT at 855.0s.
# Adversary: Start EXPLOIT_VULN at 855.0s.
# MTD: PortShuffle finished in 6.7s at 859.6s.
# MTD: Interrupted EXPLOIT_VULN at 859.6s!
# Adversary: Restarting with SCAN_PORT at 861.6s!
# Adversary: Start SCAN_PORT at 861.6s.
# Adversary: Processed SCAN_PORT at 865.6s.
# Adversary: Start EXPLOIT_VULN at 865.6s.
# Adversary: Processed EXPLOIT_VULN at 871.7s.
# Adversary: Host 53 has been compromised at 871.7s!
# Adversary: Start SCAN_NEIGHBOR at 871.7s.
# Adversary: Processed SCAN_NEIGHBOR at 873.7s.
# Adversary: Start ENUM_HOST at 873.7s.
# Adversary: Processed ENUM_HOST at 876.7s.
# Adversary: Start ENUM_HOST at 876.7s.
# Adversary: Processed ENUM_HOST at 879.7s.
# Adversary: Start ENUM_HOST at 879.7s.
# Adversary: Processed ENUM_HOST at 882.7s.
# Adversary: Start SCAN_PORT at 882.7s.
# MTD: ServiceDiversity triggered 884.5s
# MTD: ServiceDiversity deployed in the network at 884.5s.
# Adversary: Processed SCAN_PORT at 886.7s.
# Adversary: Start EXPLOIT_VULN at 886.7s.
# Adversary: Processed EXPLOIT_VULN at 891.9s.
# Adversary: Host 81 has been compromised at 891.9s!
# Adversary: Start SCAN_NEIGHBOR at 891.9s.
# MTD: ServiceDiversity finished in 8.3s at 892.8s.
# Adversary: Processed SCAN_NEIGHBOR at 893.9s.
# Adversary: Start ENUM_HOST at 893.9s.
# Adversary: Processed ENUM_HOST at 896.9s.
# Adversary: Start SCAN_PORT at 896.9s.
# Adversary: Processed SCAN_PORT at 900.9s.
# Adversary: Start EXPLOIT_VULN at 900.9s.
# Adversary: Processed EXPLOIT_VULN at 906.3s.
# Adversary: Host 94 has been compromised at 906.3s!
# Adversary: Start SCAN_NEIGHBOR at 906.3s.
# Adversary: Processed SCAN_NEIGHBOR at 908.3s.
# Adversary: Start ENUM_HOST at 908.3s.
# Adversary: Processed ENUM_HOST at 911.3s.
# Adversary: Start ENUM_HOST at 911.3s.
# Adversary: Processed ENUM_HOST at 914.3s.
# Adversary: Start ENUM_HOST at 914.3s.
# MTD: CompleteTopologyShuffle triggered 914.6s
# MTD: CompleteTopologyShuffle deployed in the network at 914.6s.
# Adversary: Processed ENUM_HOST at 917.3s.
# Adversary: Start SCAN_PORT at 917.3s.
# Adversary: Processed SCAN_PORT at 921.3s.
# Adversary: Start EXPLOIT_VULN at 921.3s.
# MTD: CompleteTopologyShuffle finished in 10.2s at 924.8s.
# MTD: Interrupted EXPLOIT_VULN at 924.8s!
# Adversary: Restarting with SCAN_HOST at 926.8s!
# Adversary: Start SCAN_HOST at 926.8s.
# Adversary: Processed SCAN_HOST at 928.8s.
# Adversary: Start ENUM_HOST at 928.8s.
# Adversary: Processed ENUM_HOST at 931.8s.
# Adversary: Start SCAN_PORT at 931.8s.
# Adversary: Processed SCAN_PORT at 935.8s.
# Adversary: Start EXPLOIT_VULN at 935.8s.
# Adversary: Processed EXPLOIT_VULN at 940.8s.
# Adversary: Host 41 has been compromised at 940.8s!
# Adversary: Start SCAN_NEIGHBOR at 940.8s.
# Adversary: Processed SCAN_NEIGHBOR at 942.8s.
# Adversary: Start ENUM_HOST at 942.8s.
# MTD: HostTopologyShuffle triggered 944.9s
# MTD: HostTopologyShuffle deployed in the network at 944.9s.
# Adversary: Processed ENUM_HOST at 945.8s.
# Adversary: Start ENUM_HOST at 945.8s.
# Adversary: Processed ENUM_HOST at 948.8s.
# Adversary: Start SCAN_PORT at 948.8s.
# Adversary: Processed SCAN_PORT at 952.8s.
# Adversary: Start EXPLOIT_VULN at 952.8s.
# MTD: HostTopologyShuffle finished in 9.2s at 954.1s.
# MTD: Interrupted EXPLOIT_VULN at 954.1s!
# Adversary: Restarting with SCAN_HOST at 956.1s!
# Adversary: Start SCAN_HOST at 956.1s.
# Adversary: Processed SCAN_HOST at 958.1s.
# Adversary: Start ENUM_HOST at 958.1s.
# Adversary: Processed ENUM_HOST at 961.1s.
# Adversary: Start SCAN_PORT at 961.1s.
# Adversary: Processed SCAN_PORT at 965.1s.
# Adversary: Start EXPLOIT_VULN at 965.1s.
# Adversary: Processed EXPLOIT_VULN at 971.0s.
# Adversary: Host 31 has been compromised at 971.0s!
# Adversary: Start SCAN_NEIGHBOR at 971.0s.
# Adversary: Processed SCAN_NEIGHBOR at 973.0s.
# Adversary: Start ENUM_HOST at 973.0s.
# MTD: IPShuffle triggered 975.1s
# MTD: IPShuffle deployed in the network at 975.1s.
# Adversary: Processed ENUM_HOST at 976.0s.
# Adversary: Start ENUM_HOST at 976.0s.
# Adversary: Processed ENUM_HOST at 979.0s.
# Adversary: Start ENUM_HOST at 979.0s.
# Adversary: Processed ENUM_HOST at 982.0s.
# Adversary: Start ENUM_HOST at 982.0s.
# MTD: IPShuffle finished in 8.5s at 983.5s.
# MTD: Interrupted ENUM_HOST at 983.5s!
# Adversary: Restarting with SCAN_HOST at 985.5s!
# Adversary: Start SCAN_HOST at 985.5s.
# Adversary: Processed SCAN_HOST at 987.5s.
# Adversary: Start ENUM_HOST at 987.5s.
# Adversary: Processed ENUM_HOST at 990.5s.
# Adversary: Start SCAN_PORT at 990.5s.
# Adversary: Processed SCAN_PORT at 994.5s.
# Adversary: Start EXPLOIT_VULN at 994.5s.
# Adversary: Processed EXPLOIT_VULN at 1000.1s.
# Adversary: Host 38 has been compromised at 1000.1s!
# Adversary: Start SCAN_NEIGHBOR at 1000.1s.
# Adversary: Processed SCAN_NEIGHBOR at 1002.1s.
# Adversary: Start ENUM_HOST at 1002.1s.
# Adversary: Processed ENUM_HOST at 1005.1s.
# Adversary: Start SCAN_PORT at 1005.1s.
# MTD: OSDiversity triggered 1005.3s
# MTD: OSDiversity deployed in the network at 1005.3s.
# Adversary: Processed SCAN_PORT at 1009.1s.
# Adversary: Start EXPLOIT_VULN at 1009.1s.
# MTD: OSDiversity finished in 7.5s at 1012.8s.
# MTD: Interrupted EXPLOIT_VULN at 1012.8s!
# Adversary: Restarting with SCAN_PORT at 1014.8s!
# Adversary: Start SCAN_PORT at 1014.8s.
# Adversary: Processed SCAN_PORT at 1018.8s.
# Adversary: Start EXPLOIT_VULN at 1018.8s.
# Adversary: Processed EXPLOIT_VULN at 1024.3s.
# Adversary: Host 41 has been compromised at 1024.3s!
# Adversary: Start SCAN_NEIGHBOR at 1024.3s.
# Adversary: Processed SCAN_NEIGHBOR at 1026.3s.
# Adversary: Start ENUM_HOST at 1026.3s.
# Adversary: Processed ENUM_HOST at 1029.3s.
# Adversary: Start ENUM_HOST at 1029.3s.
# Adversary: Processed ENUM_HOST at 1032.3s.
# Adversary: Start SCAN_PORT at 1032.3s.
# MTD: PortShuffle triggered 1035.5s
# MTD: PortShuffle deployed in the network at 1035.5s.
# Adversary: Processed SCAN_PORT at 1036.3s.
# Adversary: Start EXPLOIT_VULN at 1036.3s.
# Adversary: Processed EXPLOIT_VULN at 1041.8s.
# Adversary: Start BRUTE_FORCE at 1041.8s.
# MTD: PortShuffle finished in 6.5s at 1041.9s.
# MTD: Interrupted BRUTE_FORCE at 1041.9s!
# Adversary: Restarting with SCAN_PORT at 1043.9s!
# Adversary: Start SCAN_PORT at 1043.9s.
# Adversary: Processed SCAN_PORT at 1047.9s.
# Adversary: Start EXPLOIT_VULN at 1047.9s.
# Adversary: Processed EXPLOIT_VULN at 1053.5s.
# Adversary: Start BRUTE_FORCE at 1053.5s.
# Adversary: Processed BRUTE_FORCE at 1056.5s.
# Adversary: Start ENUM_HOST at 1056.5s.
# Adversary: Processed ENUM_HOST at 1059.5s.
# Adversary: Start SCAN_PORT at 1059.5s.
# Adversary: Processed SCAN_PORT at 1063.5s.
# Adversary: Start EXPLOIT_VULN at 1063.5s.
# MTD: ServiceDiversity triggered 1065.8s
# MTD: ServiceDiversity deployed in the network at 1065.8s.
# Adversary: Processed EXPLOIT_VULN at 1069.2s.
# Adversary: Host 18 has been compromised at 1069.2s!
# Adversary: Start SCAN_NEIGHBOR at 1069.2s.
# Adversary: Processed SCAN_NEIGHBOR at 1071.2s.
# Adversary: Start ENUM_HOST at 1071.2s.
# MTD: ServiceDiversity finished in 8.2s at 1074.0s.
# Adversary: Processed ENUM_HOST at 1074.2s.
# Adversary: Start ENUM_HOST at 1074.2s.
# Adversary: Processed ENUM_HOST at 1077.2s.
# Adversary: Start SCAN_PORT at 1077.2s.
# Adversary: Processed SCAN_PORT at 1081.2s.
# Adversary: Start EXPLOIT_VULN at 1081.2s.
# Adversary: Processed EXPLOIT_VULN at 1087.4s.
# Adversary: Host 19 has been compromised at 1087.4s!
# Adversary: Start SCAN_NEIGHBOR at 1087.4s.
# Adversary: Processed SCAN_NEIGHBOR at 1089.4s.
# Adversary: Start ENUM_HOST at 1089.4s.
# Adversary: Processed ENUM_HOST at 1092.4s.
# Adversary: Start ENUM_HOST at 1092.4s.
# Adversary: Processed ENUM_HOST at 1095.4s.
# Adversary: Start ENUM_HOST at 1095.4s.
# MTD: CompleteTopologyShuffle triggered 1096.3s
# MTD: CompleteTopologyShuffle deployed in the network at 1096.3s.
# Adversary: Processed ENUM_HOST at 1098.4s.
# Adversary: Start ENUM_HOST at 1098.4s.
# Adversary: Processed ENUM_HOST at 1101.4s.
# Adversary: Start SCAN_PORT at 1101.4s.
# Adversary: Processed SCAN_PORT at 1105.4s.
# Adversary: Start EXPLOIT_VULN at 1105.4s.
# MTD: CompleteTopologyShuffle finished in 10.2s at 1106.5s.
# MTD: Interrupted EXPLOIT_VULN at 1106.5s!
# Adversary: Restarting with SCAN_HOST at 1108.5s!
# Adversary: Start SCAN_HOST at 1108.5s.
# Adversary: Processed SCAN_HOST at 1110.5s.
# Adversary: Start ENUM_HOST at 1110.5s.
# Adversary: Processed ENUM_HOST at 1113.5s.
# Adversary: Start SCAN_PORT at 1113.5s.
# Adversary: Processed SCAN_PORT at 1117.5s.
# Adversary: Start EXPLOIT_VULN at 1117.5s.
# Adversary: Processed EXPLOIT_VULN at 1123.2s.
# Adversary: Host 30 has been compromised at 1123.2s!
# Adversary: Start SCAN_NEIGHBOR at 1123.2s.
# Adversary: Processed SCAN_NEIGHBOR at 1125.2s.
# Adversary: Start ENUM_HOST at 1125.2s.
# MTD: HostTopologyShuffle triggered 1127.9s
# MTD: HostTopologyShuffle deployed in the network at 1127.9s.
# Adversary: Processed ENUM_HOST at 1128.2s.
# Adversary: Start ENUM_HOST at 1128.2s.
# Adversary: Processed ENUM_HOST at 1131.2s.
# Adversary: Start SCAN_PORT at 1131.2s.
# Adversary: Processed SCAN_PORT at 1135.2s.
# Adversary: Start EXPLOIT_VULN at 1135.2s.
# MTD: HostTopologyShuffle finished in 9.5s at 1137.5s.
# MTD: Interrupted EXPLOIT_VULN at 1137.5s!
# Adversary: Restarting with SCAN_HOST at 1139.5s!
# Adversary: Start SCAN_HOST at 1139.5s.
# Adversary: Processed SCAN_HOST at 1141.5s.
# Adversary: Start ENUM_HOST at 1141.5s.
# Adversary: Processed ENUM_HOST at 1144.5s.
# Adversary: Start SCAN_PORT at 1144.5s.
# Adversary: Processed SCAN_PORT at 1148.5s.
# Adversary: Start EXPLOIT_VULN at 1148.5s.
# Adversary: Processed EXPLOIT_VULN at 1154.7s.
# Adversary: Host 61 has been compromised at 1154.7s!
# Adversary: Start SCAN_NEIGHBOR at 1154.7s.
# Adversary: Processed SCAN_NEIGHBOR at 1156.7s.
# Adversary: Start ENUM_HOST at 1156.7s.
# MTD: IPShuffle triggered 1158.6s
# MTD: IPShuffle deployed in the network at 1158.6s.
# Adversary: Processed ENUM_HOST at 1159.7s.
# Adversary: Start ENUM_HOST at 1159.7s.
# Adversary: Processed ENUM_HOST at 1162.7s.
# Adversary: Start ENUM_HOST at 1162.7s.
# Adversary: Processed ENUM_HOST at 1165.7s.
# Adversary: Start SCAN_PORT at 1165.7s.
# MTD: IPShuffle finished in 8.3s at 1166.9s.
# MTD: Interrupted SCAN_PORT at 1166.9s!
# Adversary: Restarting with SCAN_HOST at 1168.9s!
# Adversary: Start SCAN_HOST at 1168.9s.
# Adversary: Processed SCAN_HOST at 1170.9s.
# Adversary: Start ENUM_HOST at 1170.9s.
# Adversary: Processed ENUM_HOST at 1173.9s.
# Adversary: Start SCAN_PORT at 1173.9s.
# Adversary: Processed SCAN_PORT at 1177.9s.
# Adversary: Start EXPLOIT_VULN at 1177.9s.
# Adversary: Processed EXPLOIT_VULN at 1182.9s.
# Adversary: Host 55 has been compromised at 1182.9s!
# Adversary: Start SCAN_NEIGHBOR at 1182.9s.
# Adversary: Processed SCAN_NEIGHBOR at 1184.9s.
# Adversary: Start ENUM_HOST at 1184.9s.
# Adversary: Processed ENUM_HOST at 1187.9s.
# Adversary: Start ENUM_HOST at 1187.9s.
# MTD: OSDiversity triggered 1188.7s
# MTD: OSDiversity deployed in the network at 1188.7s.
# Adversary: Processed ENUM_HOST at 1190.9s.
# Adversary: Start ENUM_HOST at 1190.9s.
# Adversary: Processed ENUM_HOST at 1193.9s.
# Adversary: Start ENUM_HOST at 1193.9s.
# MTD: OSDiversity finished in 7.2s at 1195.9s.
# Adversary: Processed ENUM_HOST at 1196.9s.
# Adversary: Start SCAN_PORT at 1196.9s.
# Adversary: Processed SCAN_PORT at 1200.9s.
# Adversary: Start EXPLOIT_VULN at 1200.9s.
# Adversary: Processed EXPLOIT_VULN at 1206.1s.
# Adversary: Host 84 has been compromised at 1206.1s!
# Adversary: Start SCAN_NEIGHBOR at 1206.1s.
# Adversary: Processed SCAN_NEIGHBOR at 1208.1s.
# Adversary: Start ENUM_HOST at 1208.1s.
# Adversary: Processed ENUM_HOST at 1211.1s.
# Adversary: Start SCAN_PORT at 1211.1s.
# Adversary: Processed SCAN_PORT at 1215.1s.
# Adversary: Host 80 has been compromised at 1215.1s!
# Adversary: Start SCAN_NEIGHBOR at 1215.1s.
# Adversary: Processed SCAN_NEIGHBOR at 1217.1s.
# Adversary: Start ENUM_HOST at 1217.1s.
# MTD: PortShuffle triggered 1219.2s
# MTD: PortShuffle deployed in the network at 1219.2s.
# Adversary: Processed ENUM_HOST at 1220.1s.
# Adversary: Start ENUM_HOST at 1220.1s.
# Adversary: Processed ENUM_HOST at 1223.1s.
# Adversary: Start SCAN_PORT at 1223.1s.
# MTD: PortShuffle finished in 7.0s at 1226.2s.
# MTD: Interrupted SCAN_PORT at 1226.2s!
# Adversary: Restarting with SCAN_PORT at 1228.2s!
# Adversary: Start SCAN_PORT at 1228.2s.
# Adversary: Processed SCAN_PORT at 1232.2s.
# Adversary: Start EXPLOIT_VULN at 1232.2s.
# Adversary: Processed EXPLOIT_VULN at 1237.4s.
# Adversary: Host 78 has been compromised at 1237.4s!
# Adversary: Start SCAN_NEIGHBOR at 1237.4s.
# Adversary: Processed SCAN_NEIGHBOR at 1239.4s.
# Adversary: Start ENUM_HOST at 1239.4s.
# Adversary: Processed ENUM_HOST at 1242.4s.
# Adversary: Start SCAN_PORT at 1242.4s.
# Adversary: Processed SCAN_PORT at 1246.4s.
# Adversary: Start EXPLOIT_VULN at 1246.4s.
# MTD: ServiceDiversity triggered 1249.4s
# MTD: ServiceDiversity deployed in the network at 1249.4s.
# Adversary: Processed EXPLOIT_VULN at 1251.5s.
# Adversary: Host 77 has been compromised at 1251.5s!
# Adversary: Start SCAN_NEIGHBOR at 1251.5s.
# Adversary: Processed SCAN_NEIGHBOR at 1253.5s.
# Adversary: Start ENUM_HOST at 1253.5s.
# Adversary: Processed ENUM_HOST at 1256.5s.
# Adversary: Start SCAN_PORT at 1256.5s.
# MTD: ServiceDiversity finished in 8.7s at 1258.1s.
# MTD: Interrupted SCAN_PORT at 1258.1s!
# Adversary: Restarting with SCAN_PORT at 1260.1s!
# Adversary: Start SCAN_PORT at 1260.1s.
# Adversary: Processed SCAN_PORT at 1264.1s.
# Adversary: Start EXPLOIT_VULN at 1264.1s.
# Adversary: Processed EXPLOIT_VULN at 1270.6s.
# Adversary: Host 83 has been compromised at 1270.6s!
# Adversary: Start SCAN_NEIGHBOR at 1270.6s.
# Adversary: Processed SCAN_NEIGHBOR at 1272.6s.
# Adversary: Start ENUM_HOST at 1272.6s.
# Adversary: Processed ENUM_HOST at 1275.6s.
# Adversary: Start ENUM_HOST at 1275.6s.
# Adversary: Processed ENUM_HOST at 1278.6s.
# Adversary: Start ENUM_HOST at 1278.6s.
# MTD: CompleteTopologyShuffle triggered 1279.7s
# MTD: CompleteTopologyShuffle deployed in the network at 1279.7s.
# Adversary: Processed ENUM_HOST at 1281.6s.
# Adversary: Start ENUM_HOST at 1281.6s.
# Adversary: Processed ENUM_HOST at 1284.6s.
# Adversary: Start SCAN_PORT at 1284.6s.
# Adversary: Processed SCAN_PORT at 1288.6s.
# Adversary: Start EXPLOIT_VULN at 1288.6s.
# MTD: CompleteTopologyShuffle finished in 10.2s at 1289.8s.
# MTD: Interrupted EXPLOIT_VULN at 1289.8s!
# Adversary: Restarting with SCAN_HOST at 1291.8s!
# Adversary: Start SCAN_HOST at 1291.8s.
# Adversary: Processed SCAN_HOST at 1293.8s.
# Adversary: Start ENUM_HOST at 1293.8s.
# Adversary: Processed ENUM_HOST at 1296.8s.
# Adversary: Start SCAN_PORT at 1296.8s.
# Adversary: Processed SCAN_PORT at 1300.8s.
# Adversary: Start EXPLOIT_VULN at 1300.8s.
# Adversary: Processed EXPLOIT_VULN at 1306.4s.
# Adversary: Host 46 has been compromised at 1306.4s!
# Adversary: Start SCAN_NEIGHBOR at 1306.4s.
# Adversary: Processed SCAN_NEIGHBOR at 1308.4s.
# Adversary: Start ENUM_HOST at 1308.4s.
# MTD: HostTopologyShuffle triggered 1310.1s
# MTD: HostTopologyShuffle deployed in the network at 1310.1s.
# Adversary: Processed ENUM_HOST at 1311.4s.
# Adversary: Start ENUM_HOST at 1311.4s.
# Adversary: Processed ENUM_HOST at 1314.4s.
# Adversary: Start ENUM_HOST at 1314.4s.
# Adversary: Processed ENUM_HOST at 1317.4s.
# Adversary: Start ENUM_HOST at 1317.4s.
# MTD: HostTopologyShuffle finished in 9.0s at 1319.2s.
# MTD: Interrupted ENUM_HOST at 1319.2s!
# Adversary: Restarting with SCAN_HOST at 1321.2s!
# Adversary: Start SCAN_HOST at 1321.2s.
# Adversary: Processed SCAN_HOST at 1323.2s.
# Adversary: Start ENUM_HOST at 1323.2s.
# Adversary: Processed ENUM_HOST at 1326.2s.
# Adversary: Start SCAN_PORT at 1326.2s.
# Adversary: Processed SCAN_PORT at 1330.2s.
# Adversary: Start EXPLOIT_VULN at 1330.2s.
# Adversary: Processed EXPLOIT_VULN at 1335.7s.
# Adversary: Host 44 has been compromised at 1335.7s!
# Adversary: Start SCAN_NEIGHBOR at 1335.7s.
# Adversary: Processed SCAN_NEIGHBOR at 1337.7s.
# Adversary: Start ENUM_HOST at 1337.7s.
# MTD: IPShuffle triggered 1340.6s
# MTD: IPShuffle deployed in the network at 1340.6s.
# Adversary: Processed ENUM_HOST at 1340.7s.
# Adversary: Start ENUM_HOST at 1340.7s.
# Adversary: Processed ENUM_HOST at 1343.7s.
# Adversary: Start ENUM_HOST at 1343.7s.
# Adversary: Processed ENUM_HOST at 1346.7s.
# Adversary: Start SCAN_PORT at 1346.7s.
# MTD: IPShuffle finished in 8.5s at 1349.2s.
# MTD: Interrupted SCAN_PORT at 1349.2s!
# Adversary: Restarting with SCAN_HOST at 1351.2s!
# Adversary: Start SCAN_HOST at 1351.2s.
# Adversary: Processed SCAN_HOST at 1353.2s.
# Adversary: Start ENUM_HOST at 1353.2s.
# Adversary: Processed ENUM_HOST at 1356.2s.
# Adversary: Start SCAN_PORT at 1356.2s.
# Adversary: Processed SCAN_PORT at 1360.2s.
# Adversary: Start EXPLOIT_VULN at 1360.2s.
# Adversary: Processed EXPLOIT_VULN at 1365.4s.
# Adversary: Host 38 has been compromised at 1365.4s!
# Adversary: Start SCAN_NEIGHBOR at 1365.4s.
# Adversary: Processed SCAN_NEIGHBOR at 1367.4s.
# Adversary: Start ENUM_HOST at 1367.4s.
# Adversary: Processed ENUM_HOST at 1370.4s.
# Adversary: Start ENUM_HOST at 1370.4s.
# MTD: OSDiversity triggered 1370.8s
# MTD: OSDiversity deployed in the network at 1370.8s.
# Adversary: Processed ENUM_HOST at 1373.4s.
# Adversary: Start ENUM_HOST at 1373.4s.
# Adversary: Processed ENUM_HOST at 1376.4s.
# Adversary: Start ENUM_HOST at 1376.4s.
# MTD: OSDiversity finished in 7.2s at 1378.0s.
# Adversary: Processed ENUM_HOST at 1379.4s.
# Adversary: Start ENUM_HOST at 1379.4s.
# Adversary: Processed ENUM_HOST at 1382.4s.
# Adversary: Start ENUM_HOST at 1382.4s.
# Adversary: Processed ENUM_HOST at 1385.4s.
# Adversary: Start ENUM_HOST at 1385.4s.
# Adversary: Processed ENUM_HOST at 1388.4s.
# Adversary: Start ENUM_HOST at 1388.4s.
# Adversary: Processed ENUM_HOST at 1391.4s.
# Adversary: Start SCAN_PORT at 1391.4s.
# Adversary: Processed SCAN_PORT at 1395.4s.
# Adversary: Start EXPLOIT_VULN at 1395.4s.
# MTD: PortShuffle triggered 1401.1s
# MTD: PortShuffle deployed in the network at 1401.1s.
# Adversary: Processed EXPLOIT_VULN at 1404.7s.
# Adversary: Host 56 has been compromised at 1404.7s!
# Adversary: Start SCAN_NEIGHBOR at 1404.7s.
# Adversary: Processed SCAN_NEIGHBOR at 1406.7s.
# Adversary: Start ENUM_HOST at 1406.7s.
# MTD: PortShuffle finished in 6.3s at 1407.4s.
# Adversary: Processed ENUM_HOST at 1409.7s.
# Adversary: Start ENUM_HOST at 1409.7s.
# Adversary: Processed ENUM_HOST at 1412.7s.
# Adversary: Start ENUM_HOST at 1412.7s.
# Adversary: Processed ENUM_HOST at 1415.7s.
# Adversary: Start SCAN_PORT at 1415.7s.
# Adversary: Processed SCAN_PORT at 1419.7s.
# Adversary: Start EXPLOIT_VULN at 1419.7s.
# Adversary: Processed EXPLOIT_VULN at 1426.1s.
# Adversary: Host 55 has been compromised at 1426.1s!
# Adversary: Start SCAN_NEIGHBOR at 1426.1s.
# Adversary: Processed SCAN_NEIGHBOR at 1428.1s.
# Adversary: Start ENUM_HOST at 1428.1s.
# Adversary: Processed ENUM_HOST at 1431.1s.
# Adversary: Start ENUM_HOST at 1431.1s.
# MTD: ServiceDiversity triggered 1431.5s
# MTD: ServiceDiversity deployed in the network at 1431.5s.
# Adversary: Processed ENUM_HOST at 1434.1s.
# Adversary: Start SCAN_PORT at 1434.1s.
# Adversary: Processed SCAN_PORT at 1438.1s.
# Adversary: Start EXPLOIT_VULN at 1438.1s.
# MTD: ServiceDiversity finished in 8.3s at 1439.9s.
# MTD: Interrupted EXPLOIT_VULN at 1439.9s!
# Adversary: Restarting with SCAN_PORT at 1441.9s!
# Adversary: Start SCAN_PORT at 1441.9s.
# Adversary: Processed SCAN_PORT at 1445.9s.
# Adversary: Start EXPLOIT_VULN at 1445.9s.
# Adversary: Processed EXPLOIT_VULN at 1451.1s.
# Adversary: Host 57 has been compromised at 1451.1s!
# Adversary: Start SCAN_NEIGHBOR at 1451.1s.
# Adversary: Processed SCAN_NEIGHBOR at 1453.1s.
# Adversary: Start ENUM_HOST at 1453.1s.
# Adversary: Processed ENUM_HOST at 1456.1s.
# Adversary: Start ENUM_HOST at 1456.1s.
# Adversary: Processed ENUM_HOST at 1459.1s.
# Adversary: Start SCAN_PORT at 1459.1s.
# MTD: CompleteTopologyShuffle triggered 1462.1s
# MTD: CompleteTopologyShuffle deployed in the network at 1462.1s.
# Adversary: Processed SCAN_PORT at 1463.1s.
# Adversary: Start EXPLOIT_VULN at 1463.1s.
# Adversary: Processed EXPLOIT_VULN at 1468.5s.
# Adversary: Host 36 has been compromised at 1468.5s!
# Adversary: Start SCAN_NEIGHBOR at 1468.5s.
# Adversary: Processed SCAN_NEIGHBOR at 1470.5s.
# Adversary: Start ENUM_HOST at 1470.5s.
# MTD: CompleteTopologyShuffle finished in 10.1s at 1472.2s.
# MTD: Interrupted ENUM_HOST at 1472.2s!
# Adversary: Restarting with SCAN_HOST at 1474.2s!
# Adversary: Start SCAN_HOST at 1474.2s.
# Adversary: Processed SCAN_HOST at 1476.2s.
# Adversary: Start ENUM_HOST at 1476.2s.
# Adversary: Processed ENUM_HOST at 1479.2s.
# Adversary: Start SCAN_PORT at 1479.2s.
# Adversary: Processed SCAN_PORT at 1483.2s.
# Adversary: Start EXPLOIT_VULN at 1483.2s.
# Adversary: Processed EXPLOIT_VULN at 1488.6s.
# Adversary: Host 59 has been compromised at 1488.6s!
# Adversary: Start SCAN_NEIGHBOR at 1488.6s.
# Adversary: Processed SCAN_NEIGHBOR at 1490.6s.
# Adversary: Start ENUM_HOST at 1490.6s.
# MTD: HostTopologyShuffle triggered 1493.4s
# MTD: HostTopologyShuffle deployed in the network at 1493.4s.
# Adversary: Processed ENUM_HOST at 1493.6s.
# Adversary: Start ENUM_HOST at 1493.6s.
# Adversary: Processed ENUM_HOST at 1496.6s.
# Adversary: Start ENUM_HOST at 1496.6s.
# Adversary: Processed ENUM_HOST at 1499.6s.
# Adversary: Start ENUM_HOST at 1499.6s.
# Adversary: Processed ENUM_HOST at 1502.6s.
# Adversary: Start ENUM_HOST at 1502.6s.
# MTD: HostTopologyShuffle finished in 10.0s at 1503.4s.
# MTD: Interrupted ENUM_HOST at 1503.4s!
# Adversary: Restarting with SCAN_HOST at 1505.4s!
# Adversary: Start SCAN_HOST at 1505.4s.
# Adversary: Processed SCAN_HOST at 1507.4s.
# Adversary: Start ENUM_HOST at 1507.4s.
# Adversary: Processed ENUM_HOST at 1510.4s.
# Adversary: Start SCAN_PORT at 1510.4s.
# Adversary: Processed SCAN_PORT at 1514.4s.
# Adversary: Host 21 has been compromised at 1514.4s!
# Adversary: Start SCAN_NEIGHBOR at 1514.4s.
# Adversary: Processed SCAN_NEIGHBOR at 1516.4s.
# Adversary: Start ENUM_HOST at 1516.4s.
# Adversary: Processed ENUM_HOST at 1519.4s.
# Adversary: Start ENUM_HOST at 1519.4s.
# Adversary: Processed ENUM_HOST at 1522.4s.
# Adversary: Start SCAN_PORT at 1522.4s.
# MTD: IPShuffle triggered 1524.1s
# MTD: IPShuffle deployed in the network at 1524.1s.
# Adversary: Processed SCAN_PORT at 1526.4s.
# Adversary: Start EXPLOIT_VULN at 1526.4s.
# Adversary: Processed EXPLOIT_VULN at 1533.1s.
# Adversary: Host 62 has been compromised at 1533.1s!
# Adversary: Start SCAN_NEIGHBOR at 1533.1s.
# MTD: IPShuffle finished in 9.3s at 1533.4s.
# MTD: Interrupted SCAN_NEIGHBOR at 1533.4s!
# Adversary: Restarting with SCAN_HOST at 1535.4s!
# Adversary: Start SCAN_HOST at 1535.4s.
# Adversary: Processed SCAN_HOST at 1537.4s.
# Adversary: Start ENUM_HOST at 1537.4s.
# Adversary: Processed ENUM_HOST at 1540.4s.
# Adversary: Start SCAN_PORT at 1540.4s.
# Adversary: Processed SCAN_PORT at 1544.4s.
# Adversary: Start EXPLOIT_VULN at 1544.4s.
# Adversary: Processed EXPLOIT_VULN at 1550.2s.
# Adversary: Host 57 has been compromised at 1550.2s!
# Adversary: Start SCAN_NEIGHBOR at 1550.2s.
# Adversary: Processed SCAN_NEIGHBOR at 1552.2s.
# Adversary: Start ENUM_HOST at 1552.2s.
# MTD: OSDiversity triggered 1554.6s
# MTD: OSDiversity deployed in the network at 1554.6s.
# Adversary: Processed ENUM_HOST at 1555.2s.
# Adversary: Start ENUM_HOST at 1555.2s.
# Adversary: Processed ENUM_HOST at 1558.2s.
# Adversary: Start ENUM_HOST at 1558.2s.
# Adversary: Processed ENUM_HOST at 1561.2s.
# Adversary: Start ENUM_HOST at 1561.2s.
# MTD: OSDiversity finished in 7.3s at 1561.9s.
# Adversary: Processed ENUM_HOST at 1564.2s.
# Adversary: Start SCAN_PORT at 1564.2s.
# Adversary: Processed SCAN_PORT at 1568.2s.
# Adversary: Host 89 has been compromised at 1568.2s!
# Adversary: Start SCAN_NEIGHBOR at 1568.2s.
# Adversary: Processed SCAN_NEIGHBOR at 1570.2s.
# Adversary: Start ENUM_HOST at 1570.2s.
# Adversary: Processed ENUM_HOST at 1573.2s.
# Adversary: Start ENUM_HOST at 1573.2s.
# Adversary: Processed ENUM_HOST at 1576.2s.
# Adversary: Start ENUM_HOST at 1576.2s.
# Adversary: Processed ENUM_HOST at 1579.2s.
# Adversary: Start ENUM_HOST at 1579.2s.
# Adversary: Processed ENUM_HOST at 1582.2s.
# Adversary: Start ENUM_HOST at 1582.2s.
# MTD: PortShuffle triggered 1584.8s
# MTD: PortShuffle deployed in the network at 1584.8s.
# Adversary: Processed ENUM_HOST at 1585.2s.
# Adversary: Start ENUM_HOST at 1585.2s.
# Adversary: Processed ENUM_HOST at 1588.2s.
# Adversary: Start SCAN_PORT at 1588.2s.
# MTD: PortShuffle finished in 6.1s at 1591.0s.
# MTD: Interrupted SCAN_PORT at 1591.0s!
# Adversary: Restarting with SCAN_PORT at 1593.0s!
# Adversary: Start SCAN_PORT at 1593.0s.
# Adversary: Processed SCAN_PORT at 1597.0s.
# Adversary: Start EXPLOIT_VULN at 1597.0s.
# Adversary: Processed EXPLOIT_VULN at 1602.0s.
# Adversary: Start BRUTE_FORCE at 1602.0s.
# Adversary: Processed BRUTE_FORCE at 1605.0s.
# Adversary: Start ENUM_HOST at 1605.0s.
# Adversary: Processed ENUM_HOST at 1608.0s.
# Adversary: Start SCAN_PORT at 1608.0s.
# Adversary: Processed SCAN_PORT at 1612.0s.
# Adversary: Start EXPLOIT_VULN at 1612.0s.
# MTD: ServiceDiversity triggered 1614.9s
# MTD: ServiceDiversity deployed in the network at 1614.9s.
# Adversary: Processed EXPLOIT_VULN at 1617.5s.
# Adversary: Start BRUTE_FORCE at 1617.5s.
# Adversary: Processed BRUTE_FORCE at 1620.5s.
# Adversary: Start ENUM_HOST at 1620.5s.
# Adversary: Processed ENUM_HOST at 1623.5s.
# Adversary: Start ENUM_HOST at 1623.5s.
# MTD: ServiceDiversity finished in 8.6s at 1623.5s.
# Adversary: Processed ENUM_HOST at 1626.5s.
# Adversary: Start ENUM_HOST at 1626.5s.
# Adversary: Processed ENUM_HOST at 1629.5s.
# Adversary: Start SCAN_PORT at 1629.5s.
# Adversary: Processed SCAN_PORT at 1633.5s.
# Adversary: Start EXPLOIT_VULN at 1633.5s.
# Adversary: Processed EXPLOIT_VULN at 1638.7s.
# Adversary: Host 64 has been compromised at 1638.7s!
# Adversary: Start SCAN_NEIGHBOR at 1638.7s.
# Adversary: Processed SCAN_NEIGHBOR at 1640.7s.
# Adversary: Start ENUM_HOST at 1640.7s.
# Adversary: Processed ENUM_HOST at 1643.7s.
# Adversary: Start ENUM_HOST at 1643.7s.
# MTD: CompleteTopologyShuffle triggered 1645.5s
# MTD: CompleteTopologyShuffle deployed in the network at 1645.5s.
# Adversary: Processed ENUM_HOST at 1646.7s.
# Adversary: Start ENUM_HOST at 1646.7s.
# Adversary: Processed ENUM_HOST at 1649.7s.
# Adversary: Start ENUM_HOST at 1649.7s.
# Adversary: Processed ENUM_HOST at 1652.7s.
# Adversary: Start SCAN_PORT at 1652.7s.
# MTD: CompleteTopologyShuffle finished in 10.0s at 1655.5s.
# MTD: Interrupted SCAN_PORT at 1655.5s!
# Adversary: Restarting with SCAN_HOST at 1657.5s!
# Adversary: Start SCAN_HOST at 1657.5s.
# Adversary: Processed SCAN_HOST at 1659.5s.
# Adversary: Start ENUM_HOST at 1659.5s.
# Adversary: Processed ENUM_HOST at 1662.5s.
# Adversary: Start SCAN_PORT at 1662.5s.
# Adversary: Processed SCAN_PORT at 1666.5s.
# Adversary: Host 75 has been compromised at 1666.5s!
# Adversary: Start SCAN_NEIGHBOR at 1666.5s.
# Adversary: Processed SCAN_NEIGHBOR at 1668.5s.
# Adversary: Start ENUM_HOST at 1668.5s.
# Adversary: Processed ENUM_HOST at 1671.5s.
# Adversary: Start ENUM_HOST at 1671.5s.
# Adversary: Processed ENUM_HOST at 1674.5s.
# Adversary: Start ENUM_HOST at 1674.5s.
# MTD: HostTopologyShuffle triggered 1675.7s
# MTD: HostTopologyShuffle deployed in the network at 1675.7s.
# Adversary: Processed ENUM_HOST at 1677.5s.
# Adversary: Start ENUM_HOST at 1677.5s.
# Adversary: Processed ENUM_HOST at 1680.5s.
# Adversary: Start SCAN_PORT at 1680.5s.
# Adversary: Processed SCAN_PORT at 1684.5s.
# Adversary: Start EXPLOIT_VULN at 1684.5s.
# MTD: HostTopologyShuffle finished in 9.6s at 1685.3s.
# MTD: Interrupted EXPLOIT_VULN at 1685.3s!
# Adversary: Restarting with SCAN_HOST at 1687.3s!
# Adversary: Start SCAN_HOST at 1687.3s.
# Adversary: Processed SCAN_HOST at 1689.3s.
# Adversary: Start ENUM_HOST at 1689.3s.
# Adversary: Processed ENUM_HOST at 1692.3s.
# Adversary: Start SCAN_PORT at 1692.3s.
# Adversary: Processed SCAN_PORT at 1696.3s.
# Adversary: Start EXPLOIT_VULN at 1696.3s.
# Adversary: Processed EXPLOIT_VULN at 1701.8s.
# Adversary: Start BRUTE_FORCE at 1701.8s.
# Adversary: Processed BRUTE_FORCE at 1704.8s.
# Adversary: Start ENUM_HOST at 1704.8s.
# MTD: IPShuffle triggered 1706.2s
# MTD: IPShuffle deployed in the network at 1706.2s.
# Adversary: Processed ENUM_HOST at 1707.8s.
# Adversary: Start SCAN_PORT at 1707.8s.
# Adversary: Processed SCAN_PORT at 1711.8s.
# Adversary: Start EXPLOIT_VULN at 1711.8s.
# MTD: IPShuffle finished in 8.3s at 1714.5s.
# MTD: Interrupted EXPLOIT_VULN at 1714.5s!
# Adversary: Restarting with SCAN_HOST at 1716.5s!
# Adversary: Start SCAN_HOST at 1716.5s.
# Adversary: Processed SCAN_HOST at 1718.5s.
# Adversary: Start ENUM_HOST at 1718.5s.
# Adversary: Processed ENUM_HOST at 1721.5s.
# Adversary: Start SCAN_PORT at 1721.5s.
# Adversary: Processed SCAN_PORT at 1725.5s.
# Adversary: Start EXPLOIT_VULN at 1725.5s.
# Adversary: Processed EXPLOIT_VULN at 1732.0s.
# Adversary: Host 47 has been compromised at 1732.0s!
# Adversary: Start SCAN_NEIGHBOR at 1732.0s.
# Adversary: Processed SCAN_NEIGHBOR at 1734.0s.
# Adversary: Start ENUM_HOST at 1734.0s.
# MTD: OSDiversity triggered 1736.2s
# MTD: OSDiversity deployed in the network at 1736.2s.
# Adversary: Processed ENUM_HOST at 1737.0s.
# Adversary: Start ENUM_HOST at 1737.0s.
# Adversary: Processed ENUM_HOST at 1740.0s.
# Adversary: Start ENUM_HOST at 1740.0s.
# Adversary: Processed ENUM_HOST at 1743.0s.
# Adversary: Start ENUM_HOST at 1743.0s.
# MTD: OSDiversity finished in 7.1s at 1743.3s.
# Adversary: Processed ENUM_HOST at 1746.0s.
# Adversary: Start ENUM_HOST at 1746.0s.
# Adversary: Processed ENUM_HOST at 1749.0s.
# Adversary: Start ENUM_HOST at 1749.0s.
# Adversary: Processed ENUM_HOST at 1752.0s.
# Adversary: Start ENUM_HOST at 1752.0s.
# Adversary: Processed ENUM_HOST at 1755.0s.
# Adversary: Start SCAN_PORT at 1755.0s.
# Adversary: Processed SCAN_PORT at 1759.0s.
# Adversary: Start EXPLOIT_VULN at 1759.0s.
# Adversary: Processed EXPLOIT_VULN at 1765.2s.
# Adversary: Host 45 has been compromised at 1765.2s!
# Adversary: Start SCAN_NEIGHBOR at 1765.2s.
# MTD: PortShuffle triggered 1766.2s
# MTD: PortShuffle deployed in the network at 1766.2s.
# Adversary: Processed SCAN_NEIGHBOR at 1767.2s.
# Adversary: Start ENUM_HOST at 1767.2s.
# Adversary: Processed ENUM_HOST at 1770.2s.
# Adversary: Start ENUM_HOST at 1770.2s.
# MTD: PortShuffle finished in 6.2s at 1772.4s.
# Adversary: Processed ENUM_HOST at 1773.2s.
# Adversary: Start SCAN_PORT at 1773.2s.
# Adversary: Processed SCAN_PORT at 1777.2s.
# Adversary: Host 42 has been compromised at 1777.2s!
# Adversary: Start SCAN_NEIGHBOR at 1777.2s.
# Adversary: Processed SCAN_NEIGHBOR at 1779.2s.
# Adversary: Start ENUM_HOST at 1779.2s.
# Adversary: Processed ENUM_HOST at 1782.2s.
# Adversary: Start ENUM_HOST at 1782.2s.
# Adversary: Processed ENUM_HOST at 1785.2s.
# Adversary: Start ENUM_HOST at 1785.2s.
# Adversary: Processed ENUM_HOST at 1788.2s.
# Adversary: Start ENUM_HOST at 1788.2s.
# Adversary: Processed ENUM_HOST at 1791.2s.
# Adversary: Start ENUM_HOST at 1791.2s.
# Adversary: Processed ENUM_HOST at 1794.2s.
# Adversary: Start SCAN_PORT at 1794.2s.
# MTD: ServiceDiversity triggered 1796.3s
# MTD: ServiceDiversity deployed in the network at 1796.3s.
# Adversary: Processed SCAN_PORT at 1798.2s.
# Adversary: Start EXPLOIT_VULN at 1798.2s.
# Adversary: Processed EXPLOIT_VULN at 1803.3s.
# Adversary: Host 75 has been compromised at 1803.3s!
# Adversary: Start SCAN_NEIGHBOR at 1803.3s.
# MTD: ServiceDiversity finished in 8.4s at 1804.7s.

# %%
metrics.draw_network()

# %%
metrics.draw_hacker_visible()

# %%
metrics.visualise_mtd_operation()

# %%
metrics.visualise_attack_operation_group_by_host()

# %%
metrics.visualise_attack_operation()

# %%
metrics.compromise_record_by_attack_action('SCAN_PORT')
# Out:
#           name   start_time  finish_time  duration  current_host  \
# 240  SCAN_PORT  4048.450737  4068.450737      20.0            61
#
#                         current_host_uuid compromise_host  \
# 240  18345e97-0b7a-4f45-ba3e-e38e0ffdd5a4              61
#
#                      compromise_host_uuid  current_host_attempt  \
# 240  18345e97-0b7a-4f45-ba3e-e38e0ffdd5a4                     1
#
#      cumulative_attempts  cumulative_compromised_hosts      compromise_users  \
# 240                  185                             9  [Gnni, Fedora, Trix]
#
#     interrupted_in interrupted_by  color curr_host_token
# 240           None           None  green              30

# %%
metrics.compromise_record_by_attack_action('EXPLOIT_VULN')
# Out:
#              name   start_time  finish_time   duration  current_host  \
# 62   EXPLOIT_VULN  1065.964457  1091.929088  25.964630             1
# 80   EXPLOIT_VULN  1371.985470  1397.146429  25.160960            56
# 84   EXPLOIT_VULN  1442.146429  1467.477315  25.330886            58
# 131  EXPLOIT_VULN  2227.453677  2252.839860  25.386183            45
# 135  EXPLOIT_VULN  2297.839860  2323.033471  25.193611            52
# 152  EXPLOIT_VULN  2589.161144  2614.381283  25.220139            42
# 201  EXPLOIT_VULN  3390.507182  3415.851560  25.344378            59
# 220  EXPLOIT_VULN  3694.168711  3720.379508  26.210797            25
# 237  EXPLOIT_VULN  3997.984760  4023.450737  25.465977            41
# 273  EXPLOIT_VULN  4576.573508  4603.238989  26.665481            60
# 292  EXPLOIT_VULN  4882.076286  4907.410783  25.334498            26
#
#                         current_host_uuid compromise_host  \
# 62   d15803c5-2956-4ccd-bf59-e1936e363d37               1
# 80   97159de5-2ab7-46f5-9cf5-a15d0340cceb              56
# 84   8ede62f0-be31-455a-bd3c-d16816dbe527              58
# 131  e519b842-e8eb-406a-9834-5a55acc39e9c              45
# 135  b203a9ff-7c33-48ff-9d8e-4e7b43e18958              52
# 152  d7d69908-10e7-4e62-9f59-16ebbc863ea3              42
# 201  d6d71748-ba66-4d95-b0a5-0baab4c54adb              59
# 220  8f5b2bf9-7404-4804-9353-fc7b1ef543df              25
# 237  b3beec33-0329-464d-bb9b-1e440e01080b              41
# 273  066036f2-0eda-4f8d-b7e0-5cb220d0fbb0              60
# 292  73fa19a0-4378-4d51-95c7-80885b8a83bc              26
#
#                      compromise_host_uuid  current_host_attempt  \
# 62   d15803c5-2956-4ccd-bf59-e1936e363d37                     3
# 80   97159de5-2ab7-46f5-9cf5-a15d0340cceb                     3
# 84   8ede62f0-be31-455a-bd3c-d16816dbe527                     1
# 131  e519b842-e8eb-406a-9834-5a55acc39e9c                     1
# 135  b203a9ff-7c33-48ff-9d8e-4e7b43e18958                     1
# 152  d7d69908-10e7-4e62-9f59-16ebbc863ea3                     2
# 201  d6d71748-ba66-4d95-b0a5-0baab4c54adb                     1
# 220  8f5b2bf9-7404-4804-9353-fc7b1ef543df                     2
# 237  b3beec33-0329-464d-bb9b-1e440e01080b                     1
# 273  066036f2-0eda-4f8d-b7e0-5cb220d0fbb0                     3
# 292  73fa19a0-4378-4d51-95c7-80885b8a83bc                     1
#
#      cumulative_attempts  cumulative_compromised_hosts  \
# 62                    33                             0
# 80                    73                             1
# 84                   103                             2
# 131                  127                             3
# 135                  149                             4
# 152                  152                             5
# 201                  171                             6
# 220                  178                             7
# 237                  181                             8
# 273                  191                            10
# 292                  203                            11
#
#                                    compromise_users interrupted_in  \
# 62           [Simonette, Lissa, Minni, Persis, Jen]           None
# 80   [Fredrika, Prudence, Margaretta, Peria, Vanny]           None
# 84                 [Lethia, Corella, Inesita, Shir]           None
# 131     [Billye, Elizabet, Mollee, Devinne, Kissie]           None
# 135       [Nadeen, Caitrin, Olympe, Kylen, Arielle]           None
# 152      [Chantal, Doralynne, Jenine, Mommy, Jodee]           None
# 201                     [Ealasaid, Zonda, Dorothea]           None
# 220            [Madelyn, Estella, Doralia, Sosanna]           None
# 237           [Christyna, Merralee, Aurelea, Maiga]           None
# 273            [Giovanna, Kimberly, Claudia, Gelya]           None
# 292      [Anabel, Lynnelle, Arabela, Talia, Allina]           None
#
#     interrupted_by   color curr_host_token
# 62            None  yellow               2
# 80            None  yellow               5
# 84            None  yellow               6
# 131           None  yellow              12
# 135           None  yellow              15
# 152           None  yellow              18
# 201           None  yellow              24
# 220           None  yellow              27
# 237           None  yellow              29
# 273           None  yellow              32
# 292           None  yellow              37

# %%
metrics.compromise_record_by_attack_action('BRUTE_FORCE')
# Out:
# Empty DataFrame
# Columns: [name, start_time, finish_time, duration, current_host, current_host_uuid, compromise_host, compromise_host_uuid, current_host_attempt, cumulative_attempts, cumulative_compromised_hosts, compromise_users, interrupted_in, interrupted_by, color, curr_host_token]
# Index: []

# %%
metrics.mean_time_to_compromise()
# Out:
# 66.62102958712596

# %%
metrics.mtd_execution_frequency()
# Out:
# 0.02064600479150331

# %%
metrics.attack_success_rate()
# Out:
# 0.3157894736842105
